# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamad-azrin/ADALL_github/blob/main/Main_First.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Example: Replace this with the raw URL of your GitHub file
github_raw_url = 'https://raw.githubusercontent.com/mohamad-azrin/ADALL_github/refs/heads/main/laptop_prices_2024_sgd_TL.csv'
try:
    df = pd.read_csv(github_raw_url)
    print("Successfully loaded data from GitHub!")
    display(df.head())

    # plot each column in df which is numeric in histogram
    df.hist(figsize=(10, 10))
    plt.show()




except Exception as e:
    print(f"Error loading data: {e}")
    print("Please ensure the URL is correct and the file format is compatible with `pd.read_csv`.")
# Out:
# Successfully loaded data from GitHub!
#   Brand                Model                        CPU              GPU  \
# 0  Acer             Aspire 5           Intel i9-14900HK  NVIDIA RTX 4070
# 1  Acer              Nitro 5         AMD Ryzen 9 8900HX  AMD Radeon 780M
# 2  Acer              Nitro 5          AMD Ryzen 5 8600H  NVIDIA RTX 4050
# 3  Acer        TravelMate P6  Intel Core Ultra 7 15500H  NVIDIA RTX 4060
# 4  Acer  Predator Helios 300            Intel i7-14800H  NVIDIA RTX 4070
#
#    RAM_GB Storage_Type  Storage_GB  Touchscreen  Weight_kg  Screen_Size_inch  \
# 0      64          SSD         256        False       1.56              16.0
# 1      32          SSD        1024         True       1.45              14.0
# 2      32          SSD        2048        False       1.34              14.0
# 3      16          SSD        4096         True       1.18              13.3
# 4       8          SSD        1024         True       1.31              14.0
#
#    Discount_percent  Price_SGD  Brand_Discount  Member_Discount
# 0              3.27    2413.36               5           144.80
# 1              5.03    1773.75               5           124.16
# 2              4.41    1634.07               5            98.04
# 3              2.16    2362.59               5           118.13
# 4              6.93    2218.55               5           155.30
# Error loading data: name 'plt' is not defined
# Please ensure the URL is correct and the file format is compatible with `pd.read_csv`.

# %%
from google.colab import userdata
from openai import OpenAI


# Load key from Google Colab Secrets
api_key = userdata.get('OPENAI_API_KEY')


client = OpenAI(
    # This is the default and can be omitted
    api_key=api_key,
)

# Convert the first few rows to a string to send to OpenAI
data_preview = df.head(10).to_csv(index=False)
print(data_preview)

response = client.responses.create(
    model="gpt-4o-mini",
    instructions="You are an expert data scientist with extensive knowledge of predictive analysis and linear regression.",
    input=f"Dataset: Laptop prices in Singapore in 2024 (1000 samples, 13 features, 1 class)\nHere are the first 10 rows of the dataset:\n{data_preview}]",
)
print(response.output_text)
# Out:
# Brand,Model,CPU,GPU,RAM_GB,Storage_Type,Storage_GB,Touchscreen,Weight_kg,Screen_Size_inch,Discount_percent,Price_SGD,Brand_Discount,Member_Discount
# Acer,Aspire 5,Intel i9-14900HK,NVIDIA RTX 4070,64,SSD,256,False,1.56,16.0,3.27,2413.36,5,144.8
# Acer,Nitro 5,AMD Ryzen 9 8900HX,AMD Radeon 780M,32,SSD,1024,True,1.45,14.0,5.03,1773.75,5,124.16
# Acer,Nitro 5,AMD Ryzen 5 8600H,NVIDIA RTX 4050,32,SSD,2048,False,1.34,14.0,4.41,1634.07,5,98.04
# Acer,TravelMate P6,Intel Core Ultra 7 15500H,NVIDIA RTX 4060,16,SSD,4096,True,1.18,13.3,2.16,2362.59,5,118.13
# Acer,Predator Helios 300,Intel i7-14800H,NVIDIA RTX 4070,8,SSD,1024,True,1.31,14.0,6.93,2218.55,5,155.3
# Acer,Aspire 5,Intel i9-14900HK,NVIDIA RTX 4080,32,SSD,256,False,3.34,17.3,8.94,2224.12,5,155.69
# Acer,TravelMate P6,Intel i9-14900HK,NVIDIA RTX 4080,128,SSD,1024,True,1.11,13.3,11.72,3016.36,5,211.15
# Acer,Predator Helios 300,Intel Core Ultra 9 15700H,NVIDIA RTX 4070,16,SSD,2048,True,1.29,13.3,8.84,2579.29,5,180.55
# Acer,Swift 3,Intel i5-14500H,NVIDIA RTX 4050,64,SSD,4096,False,1.4,13.3,6.92,1976.94,5,98.85
# Acer,Nitro 5,Intel Core Ultra 9 15700H,NVIDIA RTX 4070,16,SSD,2048,False,1.15,13.3,5.25,2538.34,5,152.3
#
# The provided dataset contains information about laptop prices in Singapore for the year 2024, featuring several attributes that can be used for predictive analysis. Here's a breakdown of the features and their potential significance, as well as steps you might take to analyze or model the data:
#
# ### Features Breakdown
#
# 1. **Brand**: The manufacturer of the laptop. This can influence price due to brand reputation.
# 2. **Model**: Specific model names that may have different specifications affecting pricing.
# 3. **CPU**: The processor type. Performance metrics from different CPUs can be significant predictors of price.
# 4. **GPU**: The graphics card type. Similar to CPUs, advanced GPUs typically raise price.
# 5. **RAM_GB**: Amount of RAM available, which can affect multitasking capability and overall performance.
# 6. **Storage_Type**: Type of storage (e.g., SSD) can influence speed and reliability (SSD vs. HDD).
# 7. **Storage_GB**: Storage capacity, which correlates with usage options for consumers.
# 8. **Touchscreen**: Whether the laptop has a touchscreen. This can be a premium feature.
# 9. **Weight_kg**: Portability aspect that could influence price.
# 10. **Screen_Size_inch**: Larger screens may denote higher prices due to enhanced consumer appeal.
# 11. **Discount_percent**: The discount offered on the laptop can directly lower the purchase cost.
# 12. **Price_SGD**: The target variable that you want to predict.
# 13. **Brand_Discount**: Potential brand-specific discounts that affect the final price.
# 14. **Member_Discount**: Discounts available to members that might influence price.
#
# ### Analysis Steps
#
# 1. **Data Cleaning**:
#    - Check for missing or inconsistent data.
#    - Convert categorical variables (like `Brand`, `Model`, `CPU`, `GPU`, and `Storage_Type`) using one-hot encoding or label encoding based on the analysis type.
#
# 2. **Exploratory Data Analysis (EDA)**:
#    - Visualize distributions of numerical features (like `Price_SGD` and `RAM_GB`).
#    - Use boxplots to visualize the impact of categorical features on the price.
#    - Analyze correlation coefficients between features and `Price_SGD`.
#
# 3. **Feature Engineering**:
#    - Create new features if necessary, such as computing `total_discount` from `Brand_Discount` and `Member_Discount`.
#    - Normalize or standardize features that have significantly different scales.
#
# 4. **Modeling with Linear Regression**:
#    - Split the dataset into training and testing sets.
#    - Fit a linear regression model using features to predict the `Price_SGD`.
#    - Check assumptions of linear regression (linearity, independence, homoscedasticity, normality).
#
# 5. **Model Evaluation**:
#    - Analyze R-squared and adjusted R-squared values to understand variance explained by the model.
#    - Examine residual plots to assess model fit.
#    - Consider cross-validation to validate model robustness.
#
# 6. **Improvement and Tuning**:
#    - Explore polynomial regression or other regression techniques, like Ridge or Lasso regression, to handle multicollinearity and improve performance.
#
# 7. **Conclusion**:
#    - Analyze the model coefficients to determine which features have the most significant impact on the price.
#    - Make business recommendations based on findings.
#
# ### Implementation (Optional)
#
# If you'd like a specific implementation or more detailed steps on any of the above points (e.g., code snippets), feel free to ask!
